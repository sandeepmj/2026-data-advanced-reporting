# %% [markdown]
# # Instructor Import

# %%
import pandas as pd

# %% [markdown]
# # Quick warm up
#
# In 2025, the ACME company had `$5.3 million` dollars in widget sales. It had expenses of `$2.6 million` and paid `$875,000` in taxes. What was its net profit?"
#
# In a sentence that uses variables (do not hard code the numbers), print an output that reads:
#
# `In 2025, the ACME company had XXXX in net profits, on XXXX in sales. It had xxxx in expenses and paid xxxx in taxes".

# %%
## Code here
acme_sales = 5_300_000
acme_expenses = 2_600_000
acme_taxes = 875_000

# or 
# calling it a_ just to distinguish from above
a_sales, a_expenses, a_taxes = 5_300_000, 2_600_000, 875_000

# %%
# calculation
acme_net = acme_sales - (acme_expenses + acme_taxes)
print(acme_net)
# Out:
# 1825000

# %%
## print statement
print(f"In 2025, the ACME company had ${acme_net:,} in net profits, on ${acme_sales:,} in sales.\
It had ${acme_expenses:,} in expenses and paid ${acme_taxes:,} in taxes")
# Out:
# In 2025, the ACME company had $1,825,000 in net profits, on $5,300,000 in sales.It had $2,600,000 in expenses and paid $875,000 in taxes

# %% [markdown]
# # Python Data Types

# %% [markdown]
# ## Object-Oriented
#
# Python Is `Object-Oriented` language.
#
# That simply means everything in Python is an object. And all objects can:
# 1. Hold data (`datatypes`).
# 2. Have actions done to them (`methods`) or sometimes interchangeably called `built-in functions`.

# %% [markdown]
# This make Python the perfect language for data journalists to collect, clean, analyze, and automate work with structured information in a powerful and reproducible way.

# %% [markdown]
# # Built-in Functions (methods)
# You've encountered a built-in function in ```print()```
#
# In simplest terms (good for now), a ```built-in function``` comes as standard part of Python and carries out one or more steps on something we aim it at. What we target for the function goes inside the parenthesis. You've already used a built-in function:
#
# ```print("output something")```
#
# Another is `abs()` which converts a negative number to a positive number.
#
# - Create a variable called some_number and assign it a negative value
# - Turn it into a positive number

# %%
## write a negative number
-11
# Out:
# -11

# %%
##### Convert a number into an absolute
## create a variable called some_number with a negative value
## covert it to an absolute number
abs(-11)
# Out:
# 11

# %%
## how long was is your nanme?
len("sandeep")
# Out:
# 7

# %%
## what type of data is "Sandeep"
type("sandeep")
# Out:
# str

# %%
## what type of data is a 45?
type(45)
# Out:
# int

# %%
## what type of data is 3.28
type(3.28)
# Out:
# float

# %% [markdown]
# I will introduce others through the course as need. There are <a href="https://docs.python.org/3/library/functions.html">dozens of built-in functions</a>, but I will be introducing the most useful ones little by little.

# %% [markdown]
# ### ```Lists```
# Lists are the most widely used data containers in Python.
#
# - Wrap your data in square brackets ```[]``` to create a list.
# - A list can hold anything and everything in Python:
#     - numbers
#     - strings
#     - other lists
#     - dictionaries (more on this today)
#     - booleans (more on this at some point)
#     - functions (more on this in the next level course)

# %%
## create a list that holds the following terms
### give some animals

animals = ["rat", "cat", "horse", "bee", "manatee", "rabbit", "shrimp"]
animals
# Out:
# ['rat', 'cat', 'horse', 'bee', 'manatee', 'rabbit', 'shrimp']

# %%
## check the type
type(animals)
# Out:
# list

# %%
## length of list
len(animals)
# Out:
# 7

# %%
##build a list with mixed items like strings, numbers, bools, lists etc.
mixed_list = ["Sandeep", 1, "5", True, False, "True", "false", 10, animals, "animals"]

mixed_list
# Out:
# ['Sandeep',
#  1,
#  '5',
#  True,
#  False,
#  'True',
#  'false',
#  10,
#  ['rat', 'cat', 'horse', 'bee', 'manatee', 'rabbit', 'shrimp'],
#  'animals']

# %%
print(mixed_list)
# Out:
# ['Sandeep', 1, '5', True, False, 'True', 'false', 10, ['rat', 'cat', 'horse', 'bee', 'manatee', 'rabbit', 'shrimp'], 'animals']

# %%
## how many items are in mixed_list
len(mixed_list)
# Out:
# 10

# %% [markdown]
# ## Why is a ```list``` even remotely of relevance to us?

# %%
## NO NEED FOR STUDENTS TO TYPE THIS OUT
## JUST RUN IT TO SEE OUTPUT
df = pd.DataFrame(animals)
df.columns = ["fav_animal"]
df.to_csv("animals.csv", encoding = "UTF-8", index = False)

# %% [markdown]
# ### Full circle with a  ```list```:
#
# A  ```list``` is **a single column** in a spreadsheet:
#
# ![Screen Shot 2023-01-26 at 8.18.57 AM.png](data:image/png;base64,...)

# %% [markdown]
# # ```Dictionaries```
#
# A Python ```Dictionary```, or ```dict``` is another common and powerful datatype.
#
# Think of it as a collection of data points about a single element.
#
# For example, a car model:
#
# - brand: Audi
# - body: SUV
# - model: Q4
# - trim: Leather
# - cost: 60_000
# - on_sale: False
# - vin: 2973
# - type: EV
#
# A dictionary would hold this data as **key: value** pairs
#
# A dictionary is wrapped in ```{}```.
#
# Each key: value pair is separated by a comma.
#
# The format is ```{"key1_string": "string_value", "key2_number": 12, "key3_bolean": True}```

# %%
## build AND CALL the car_1 dictionary
car_1 = {"brand": "Audi",
         "body": "SUV",
        "model": "Q4",
        "trim": "leather",
        "cost": 60_000,
        "on_sale": False,
        "VIN": "2990",
        "type": "EV"}

car_1
# Out:
# {'brand': 'Audi',
#  'body': 'SUV',
#  'model': 'Q4',
#  'trim': 'leather',
#  'cost': 60000,
#  'on_sale': False,
#  'VIN': '2990',
#  'type': 'EV'}

# %%
## build and call car_2
car_2 = {"VIN": "8303",
        "brand": "Honda",
        "body": "Sedan",
        "model": "Accord",
        "type": "gas",
        "trim": "cloth",
        "cost": 42_000,
        "on_sale": True}
car_2
# Out:
# {'VIN': '8303',
#  'brand': 'Honda',
#  'body': 'Sedan',
#  'model': 'Accord',
#  'type': 'gas',
#  'trim': 'cloth',
#  'cost': 42000,
#  'on_sale': True}

# %% [markdown]
# ### A ```list``` can holds ```dicts```

# %%
## create a list called cars_list here
cars_list = [car_1, car_2]

cars_list
# Out:
# [{'brand': 'Audi',
#   'body': 'SUV',
#   'model': 'Q4',
#   'trim': 'leather',
#   'cost': 60000,
#   'on_sale': False,
#   'VIN': '2990',
#   'type': 'EV'},
#  {'VIN': '8303',
#   'brand': 'Honda',
#   'body': 'Sedan',
#   'model': 'Accord',
#   'type': 'gas',
#   'trim': 'cloth',
#   'cost': 42000,
#   'on_sale': True}]

# %% [markdown]
# ### Why is a ```list``` that holds ```dicts``` even remotely of relevance to us?

# %%
## JUST RUN TO DEMO
## NO NEED FOR STUDENTS TO TYPE
df = pd.DataFrame(cars_list)
df.to_csv("cars.csv", encoding = "UTF-8", index = False)

# %%
## call df
df
# Out:
#    brand   body   model     trim   cost  on_sale   VIN type
# 0   Audi    SUV      Q4  leather  60000    False  2990   EV
# 1  Honda  Sedan  Accord    cloth  42000     True  8303  gas

# %% [markdown]
# #### List of Dictionaries
#
# We come full circle. A list of dictionaries is equivalent to **data as columns and rows**  in a CSV file. Here, I exported and opened this data in Excel:
#
# <img src = "https://sandeepmj.github.io/datasets/cars-df.png">

# %% [markdown]
# # Python v. Python Libraries & Packages
# <a href="https://docs.google.com/presentation/d/1N2JEVCGw_cbwK2zY-WoUK8jctrShH2Aa4CzB5U-uIJE/edit?usp=sharing">What's the difference and why does it matter</a>?

# %% [markdown]
# ## import library
# import pandas as pd

# %% [markdown]
# ## Import CSV data into our Colab notebook
#
# Download this data:
#
#
# *   <a href="https://github.com/sandeepmj/datasets/blob/main/importing/insurance.csv">Insurance by region</a>

# %% [markdown]
# ### Read a CSV file into your notebook

# %% [markdown]
# #### Bring in ```insurance.csv``` into Pandas
#
# - You must provide a ```path``` to the file you are importing.
#
# Syntax: ```pd.read_csv("path_to_file")```

# %%
## simply read the csv file when data file is at the same level
pd.read_csv("insurance.csv")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]
